# %% [markdown]
# <a href="https://colab.research.google.com/github/zoybathecodess/Digital-Reputation-Score-for-Small-Businesses/blob/main/fake_review_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/ScoreShield_12000_Rows_With_Platforms.xlsx")

# %%
df2 = df.sample(100)

# %%
df2.to_csv('fake_review_sample.csv')
