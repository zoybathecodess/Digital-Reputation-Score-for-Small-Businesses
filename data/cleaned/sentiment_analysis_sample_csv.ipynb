# %% [markdown]
# <a href="https://colab.research.google.com/github/zoybathecodess/Digital-Reputation-Score-for-Small-Businesses/blob/main/sentiment_analysis_sample_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cleaned_data.csv')

# %%
df2 = df.sample(100)

# %%
df2.to_csv("sentiment_analysis_sample.csv")
